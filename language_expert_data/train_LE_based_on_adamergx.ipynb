# %%
# git clone Modular-LLM
# checkout to language expert branch

# !unzip /content/Modular-LLM.zip
# Out:
# Archive:  /content/Modular-LLM.zip
#    creating: Modular-LLM/
#    creating: Modular-LLM/.git/
#   inflating: Modular-LLM/.git/config
#   inflating: Modular-LLM/.git/description
#   inflating: Modular-LLM/.git/HEAD
#    creating: Modular-LLM/.git/hooks/
#   inflating: Modular-LLM/.git/hooks/applypatch-msg.sample
#   inflating: Modular-LLM/.git/hooks/commit-msg.sample
#   inflating: Modular-LLM/.git/hooks/fsmonitor-watchman.sample
#   inflating: Modular-LLM/.git/hooks/post-update.sample
#   inflating: Modular-LLM/.git/hooks/pre-applypatch.sample
#   inflating: Modular-LLM/.git/hooks/pre-commit.sample
#   inflating: Modular-LLM/.git/hooks/pre-merge-commit.sample
#   inflating: Modular-LLM/.git/hooks/pre-push.sample
#   inflating: Modular-LLM/.git/hooks/pre-rebase.sample
#   inflating: Modular-LLM/.git/hooks/pre-receive.sample
#   inflating: Modular-LLM/.git/hooks/prepare-commit-msg.sample
#   inflating: Modular-LLM/.git/hooks/push-to-checkout.sample
# ...

# %%
# %cd /content/Modular-LLM/scripts
# Out:
# /content/Modular-LLM/scripts

# %%
# !pip install -r /content/Modular-LLM/requirements.txt
# Out:
# ...
#   Cloning https://github.com/EricLBuehler/xlora.git to /tmp/pip-req-build-ys7l2ofj
#   Running command git clone --filter=blob:none --quiet https://github.com/EricLBuehler/xlora.git /tmp/pip-req-build-ys7l2ofj
#   Resolved https://github.com/EricLBuehler/xlora.git to commit 8217992c8dcf5a1c025749a48e665c59cc0b6350
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.1/44.1 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 34.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.4/122.4 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 310.2/310.2 kB 26.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.0/10.0 MB 117.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.0/84.0 kB 8.4 MB/s eta 0:00:00
# ...

# %%
import wandb

# Log in using your API key
wandb.login(key="04f00213efa3cfba53b64050f7057c17304faec5")
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: W&B API key is configured. Use `wandb login --relogin` to force relogin
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# 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
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To login, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
from huggingface_hub import HfApi, hf_hub_download

# Authenticate (this requires your token if it's a private repo)
api = HfApi()
repo_id = "AliEdalat/LE_dataset_5token_pred"  # Replace with your repo

# List all files in the repository
files_in_repo = api.list_repo_files(repo_id=repo_id, repo_type="dataset")

# Download all files
for file_name in files_in_repo:
    file_path = hf_hub_download(repo_id=repo_id, filename=file_name, repo_type="dataset", use_auth_token=True)
    print(f"Downloaded {file_name} to {file_path}")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# .gitattributes:   0%|          | 0.00/2.57k [00:00<?, ?B/s]
# Downloaded .gitattributes to /root/.cache/huggingface/hub/datasets--AliEdalat--LE_dataset_5token_pred/snapshots/f08bedce02865984f127af7e3ba9796c8c51f583/.gitattributes
# en_Wiki_10k_LM_511_1 (1).json:   0%|          | 0.00/33.1M [00:00<?, ?B/s]
# ...

# %%
import pandas as pd

te = pd.read_json('/root/.cache/huggingface/hub/datasets--AliEdalat--LE_dataset_5token_pred/snapshots/f08bedce02865984f127af7e3ba9796c8c51f583/en_Wiki_10k_LM_511_1 (1).json')
te.sample(n=2000, random_state=1).to_json('en.json', orient='records')

# %%
# !ls
# Out:
# en.json  train_module_le.sh  train_modules.sh

# %%
# !chmod 777 train_module_le.sh
# !sh ./train_module_le.sh
# Out:
# 2024-11-03 09:06:38.991150: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-11-03 09:06:39.013094: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-11-03 09:06:39.019634: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-11-03 09:06:39.044524: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...
